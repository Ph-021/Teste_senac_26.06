# %%
'''print("oi")'''
# Out:
# oi

# %%
'''nome = []
estado = []
idade = []

for i in range(3):
    candidato = input("Nome: ")
    estado_candidato = input("Estado: ")
    idade_candidato = int(input("Idade: "))

    if idade_candidato >= 18:
      nome.append(candidato)
      estado.append(candidato)
      idade.append(candidato)
    else:
      print("A vaga é para apenas para candidatos maiores de idade")

for i in range(len(nome)):
   print(f"O candidato {nome[i]} está cadastrado.")'''
# Out:
#   Cell In[5], line 18
#     print(f"O candidato {nome{i}} está cadastrado.")
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
'''temp = []

for i in range(6):
    temp_hab = int(input("Digite a temperatura: "))
    if temp_hab <= 14:
        print(f"A temperatura {temp_hab}, está fria")
    elif temp_hab <=28:
        print(f"A temperatura {temp_hab}, está agradavel")
    else:
        print(f"A temperatura {temp_hab}, está quente")
'''
# Out:
# A temperatura 20, está agradavel
# A temperatura 60, está quente
# A temperatura 14, está fria
# A temperatura 25, está agradavel
# A temperatura 30, está quente
# A temperatura 8, está fria

# %%
'''produto = ["baby beed", "figado", "sobre coxa"]
preco = [70, 15, 20]

total = sum(preco)
maior_valor = max(preco)
menor_valor = min(preco)

indice_caro = preco.index(maior_valor)
indice_barato = preco.index(menor_valor)

print(f"O produto mais caro é o {produto[indice_caro]} e custa {maior_valor}")
print(f"O produto mais barato é o {produto[indice_barato]} e custa {menor_valor}")'''
# Out:
# O produto mais caro é o baby beed e custa 70
# O produto mais barato é o figado e custa 15

# %%
'''aluno = {
    "nome" : "Carlos",
    "idade" : 20,
    "curso" : "Analista de Dados",
    "Ativo" : True
}

print(aluno["nome"])'''
# Out:
# Carlos

# %%
'''aluno.get("cidade", "chave não existe")'''
# Out:
# 'chave não existe'

# %%
'''aluno["email"] = "carlossenac@gmail.com"
aluno["turma"] = "A1"'''

# %%
'''candidatos = {
    "nomes": ["Goku", "Vegeta", "Gohan"],
    "idades": [16, 18, 14],
    "cidades":["Niteroi", "Rio", "Sao Paulo"],
    "vagas": ["Analista", "Dev", "Cientista"]
}

print(candidatos["nomes"])'''
# Out:
# ['Goku', 'Vegeta', 'Gohan']

# %%
'''# 1. Inicialização do dicionário com listas vazias (REFERENCIA DO CHAT)
candidatos = {
    "nomes": [],
    "idades": [],
    "cidades": [],
    "estados": [],
    "vagas": []
}

# 2. Laço para cadastrar os 4 candidatos
print("--- CADASTRO DE CANDIDATOS ---")
for i in range(4):
    print(f"\nDigite os dados do {i+1}º candidato:")
    
    # Adicionando os dados digitados diretamente nas listas do dicionário
    candidatos["nomes"].append(input("Nome: "))
    candidatos["idades"].append(input("Idade: "))
    candidatos["cidades"].append(input("Cidade: "))
    candidatos["estados"].append(input("Estado: "))
    candidatos["vagas"].append(input("Vaga pretendida: "))

print("\n" + "="*50)

# 3. Laço para exibir os prints formatados
print("--- RESULTADO DOS CADASTROS ---")
for i in range(4):
    print(f"Candidato {candidatos['nomes'][i]}, {candidatos['idades'][i]} anos, "
          f"morador de {candidatos['cidades'][i]}, {candidatos['estados'][i]}, "
          f"candidatou para vaga de {candidatos['vagas'][i]}.")'''
# Out:
# --- CADASTRO DE CANDIDATOS ---
#
# Digite os dados do 1º candidato:
#
# Digite os dados do 2º candidato:
#
# Digite os dados do 3º candidato:
#
# Digite os dados do 4º candidato:
#
# ...
# --- RESULTADO DOS CADASTROS ---
# Candidato ,  anos, morador de , , candidatou para vaga de .
# Candidato ,  anos, morador de , , candidatou para vaga de .
# Candidato ,  anos, morador de , , candidatou para vaga de .
# Candidato ,  anos, morador de , , candidatou para vaga de .

# %%
'''sair = "SIM"
candidatos = {
    "nomes": [],
    "idades": [],
    "cidades":[],
    "vagas":  []
}

while sair == "SIM":
    nome = input("Nome: ")
    idade = int(input("idade: "))
    Cidade = input("ciadade: ")
    vaga = input("Vaga: ")

    candidatos["nomes"].append(nome)
    candidatos["idades"].append(idade)
    candidatos["cidades"].append(Cidade)
    candidatos["vagas"].append(vaga)
    sair = input("Deseja cadastrar mais canditados? ").strip().upper()

for i in range(len(candidatos['nomes'])):
    print(f'O candidato {candidatos["nomes"][i]} tem {candidatos['idades'][i]}')'''

# %%
'''while True:
    try:
        num1 = float(input("Digite o primeiro número: "))
        operacao = input("Digite a operação (+, -, *, /): ")
        num2 = float(input("Digite o segundo número: "))

        if operacao not in ("+", "-", "*", "/"):
            print("Erro: operação inválida. Use apenas +, -, * ou /.")
            continue

    except ValueError:
        print("Erro: digite um número válido.")
        continue

    else:
        try:
            if operacao == "+":
                resultado = num1 + num2
            elif operacao == "-":
                resultado = num1 - num2
            elif operacao == "*":
                resultado = num1 * num2
            elif operacao == "/":
                resultado = num1 / num2

            print(f"Resultado: {resultado}")
            break

        except ZeroDivisionError:
            print("Erro: não é possível dividir por zero.")
'''

# %%
'''numeros = []
for i in range(1, 6):
    
    while True:
        try:
            valor = float(input(f"Digite o {i}º número: "))

            
            numeros.append(valor)
            
            
            break
            
        except ValueError:
            
            print("Ops! Isso não é um número válido. Tente novamente.")

---


print("\nParabéns! Todos os números foram cadastrados com sucesso.")
print(f"Os números digitados foram: {numeros}")'''
# Out:
#   Cell In[12], line 23
#     ---
#        ^
# SyntaxError: invalid syntax

# %%
'''def saudacao():
    print("Olá, Bem-vindo ao SENAC RJ")
    '''

# %%
'''saudacao()'''
# Out:
# Olá, Bem-vindo ao SENAC RJ

# %%
'''def saudacao(nome):
    print(f"Olá, {nome}! Bem-vindo ao SENAC RJ")'''

# %%
'''saudacao('hugo')'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 saudacao('hugo')
#
# TypeError: saudacao() takes 0 positional arguments but 1 was given

# %%
'''def calcular_dobro(num):
    resultado = num * 2
    return resultado'''

# %%
'''calcular_dobro(5)'''
# Out:
# 10

# %%
'''def saudacoes(nome = "visitante"):
    print(f"Olá {nome}")'''

# %%
'''saudacoes()'''
# Out:
#   Cell In[10], line 1
#     saudacoes(nome=)
#               ^
# SyntaxError: expected argument value expression

# %%
'''def calcular_media(lista_notas):
    soma = sum(lista_notas)
    media = soma / len(lista_notas)
    return media'''

# %%
'''alunos = {"Lucas" : [7,8,5,7],
          "Karol" : [10,5,7,6]}
resultado = calcular_media(alunos["Karol"])
print(resultado)'''
# Out:
# 7.0

# %%
'''def calcular_area():
    base1 = float(input("Digite a base: "))
    altura1 = float(input("Digite a altura: "))
    resultado_final1 = base1 * altura1
    print(f"O resultado final ficou de: {resultado_final1}")


for i in range(3):
    calcular_area()  '''

# %%
'''def tratar_n_float(mensagem):
    while True:
        try:
            valor = float(input(mensagem))
            return valor
        except ValueError:
            print("Digite um numero valido")

def calcular_area(a,b):
    area = a * b
    return area'''
